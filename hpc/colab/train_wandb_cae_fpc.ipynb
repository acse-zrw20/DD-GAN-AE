# %%
# !rm -r DD-GAN-AE
# !git clone https://github.com/acse-zrw20/DD-GAN-AE
# !pip install ./DD-GAN-AE/
# !pip install wandb
# Out:
# rm: cannot remove 'DD-GAN-AE': No such file or directory
# Cloning into 'DD-GAN-AE'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 225 (delta 92), reused 167 (delta 37), pack-reused 0
# Receiving objects: 100% (225/225), 363.48 KiB | 8.45 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Processing ./DD-GAN-AE
# Building wheels for collected packages: DD-GAN-AE
#   Building wheel for DD-GAN-AE (setup.py) ... done
#   Created wheel for DD-GAN-AE: filename=DD_GAN_AE-1.0-cp37-none-any.whl size=13608 sha256=de00eba6346bf7c991a7d347ac46d93bfc2b6b9084f177895e86ce49a24f3994
#   Stored in directory: /root/.cache/pip/wheels/4b/73/37/d356abe7b41a5356ad9335d49b8c7680932bbf11cf9ffc6cf1
# Successfully built DD-GAN-AE
# Installing collected packages: DD-GAN-AE
# Successfully installed DD-GAN-AE-1.0
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/e0/b4/9d92953d8cddc8450c859be12e3dbdd4c7754fb8def94c28b3b351c6ee4e/wandb-0.10.32-py2.py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 3.9MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/1c/4a/a54b254f67d8f4052338d54ebe90126f200693440a93ef76d254d581e3ec/sentry_sdk-1.1.0-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 12.1MB/s
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 6.9MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.12.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/bc/91/b38c4fabb6e5092ab23492ded4f318ab7299b19263272b703478038c0fbc/GitPython-3.1.18-py3-none-any.whl (170kB)
#      |████████████████████████████████| 174kB 10.8MB/s
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Collecting pathtools
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/fd/01/ff260a18caaf4457eb028c96eeb405c4a230ca06c8ec9c1379f813caa52e/configparser-5.0.2-py3-none-any.whl
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.5.30)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.0->wandb) (57.0.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/ea/e8/f414d1a4f0bbc668ed441f74f44c116d9816833a48bf81d22b697090dba8/gitdb-4.0.7-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 6.8MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.0; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.7.4.3)
# Collecting smmap<5,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/68/ee/d540eb5e5996eb81c26ceffac6ee49041d473bc5125f2aa995cf51ec1cf1/smmap-4.0.0-py2.py3-none-any.whl
# Building wheels for collected packages: subprocess32, pathtools
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp37-none-any.whl size=6502 sha256=efe348e1227ee31c05b1d1334f7d735e5025a1b475ff45b5c1ce5a505a3eeec5
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp37-none-any.whl size=8807 sha256=987831503ade437c34c465cdf91b90b6d71579c4eea0be61d17b04cfaba3b839
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built subprocess32 pathtools
# Installing collected packages: docker-pycreds, sentry-sdk, subprocess32, smmap, gitdb, GitPython, shortuuid, pathtools, configparser, wandb
# Successfully installed GitPython-3.1.18 configparser-5.0.2 docker-pycreds-0.4.0 gitdb-4.0.7 pathtools-0.1.2 sentry-sdk-1.1.0 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 wandb-0.10.32

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import wandb
import tensorflow as tf
from ddganAE.models import CAE
from ddganAE.architectures import * 
from ddganAE.wandb import train_wandb_cae
from ddganAE.preprocessing import convert_2d
from tensorflow.keras.layers.experimental import preprocessing
import numpy as np
from sklearn.model_selection import train_test_split

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# Configuration options for hyperparameter optimization
sweep_config = {
    'method': 'random',
    'metric': {
      'name': 'valid_loss',
      'goal': 'minimize'  
    },
    'parameters': {    
      'architecture': {
        'values': ['denser_omata', 'densest_omata', 'wider_omata', 'deeper_omata', 'wide_omata']
      },
      'activation': {
        'values': ['elu']
      },
      'dense_activation': {
        'values': ['relu', None]
      },
      'batch_size': {
        'values': [64, 128]
      },
      'learning_rate': {
        'values': [5e-4, 5e-5, 5e-6]
      },
      'optimizer': {
          'values': ['nadam', 'adam', 'sgd']
      },
      'momentum': {
          'values': [0.8, 0.9, 0.98]
      },
      'beta_2': {
          'values': [0.9, 0.999, 0.99999]
      }
    }
}

sweep_config['parameters']['datafile'] = {'values': ["/content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy"]}

sweep_id = wandb.sweep(sweep_config, project='cae-fpc', entity='zeff020')
wandb.agent(sweep_id, train_wandb_cae, count=200)
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Create sweep with ID: nunpy3f7
# Sweep URL: https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7
# wandb: Agent Starting Run: azlmevuy with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 0.0005
# wandb: 	momentum: 0.98
# wandb: 	optimizer: adam
# wandb: Currently logged in as: zeff020 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/azlmevuy" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/azlmevuy</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_225543-azlmevuy</code><br/><br/>
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# <br/>Waiting for W&B process to finish, PID 299<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_225543-azlmevuy/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_225543-azlmevuy/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00169</td></tr><tr><td>train_accuracy</td><td>0.98897</td></tr><tr><td>valid_loss</td><td>0.00179</td></tr><tr><td>valid_accuracy</td><td>0.98325</td></tr><tr><td>_runtime</td><td>791</td></tr><tr><td>_timestamp</td><td>1624576134</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇███████████▇██▇███████</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▅▅▆▅▆▇▇▇▇▇▇▇█▆██▇██▇▇▇▇▇▇█▇▇▇███████▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-sweep-1</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/azlmevuy" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/azlmevuy</a><br/>
# wandb: Agent Starting Run: udw9qdmv with config:
# wandb: 	activation: elu
# wandb: 	architecture: wider_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.9
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.8
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">apricot-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/udw9qdmv" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/udw9qdmv</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_230858-udw9qdmv</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 27575<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_230858-udw9qdmv/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_230858-udw9qdmv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00686</td></tr><tr><td>train_accuracy</td><td>0.96889</td></tr><tr><td>valid_loss</td><td>0.00699</td></tr><tr><td>valid_accuracy</td><td>0.95766</td></tr><tr><td>_runtime</td><td>579</td></tr><tr><td>_timestamp</td><td>1624576717</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▅▅▅▅▅▅▅▆▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇█▇▇▇▇▇██▇██▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">apricot-sweep-2</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/udw9qdmv" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/udw9qdmv</a><br/>
# wandb: Agent Starting Run: h654n5dj with config:
# wandb: 	activation: elu
# wandb: 	architecture: deeper_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.98
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">morning-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/h654n5dj" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/h654n5dj</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_231842-h654n5dj</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 54836<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_231842-h654n5dj/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_231842-h654n5dj/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.05875</td></tr><tr><td>train_accuracy</td><td>0.93526</td></tr><tr><td>valid_loss</td><td>0.05656</td></tr><tr><td>valid_accuracy</td><td>0.92378</td></tr><tr><td>_runtime</td><td>491</td></tr><tr><td>_timestamp</td><td>1624577213</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▅▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">morning-sweep-3</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/h654n5dj" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/h654n5dj</a><br/>
# wandb: Agent Starting Run: nt51sgpm with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.9
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 0.0005
# wandb: 	momentum: 0.98
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">super-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/nt51sgpm" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/nt51sgpm</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_232657-nt51sgpm</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 70895<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_232657-nt51sgpm/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_232657-nt51sgpm/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>nan</td></tr><tr><td>train_accuracy</td><td>0.50806</td></tr><tr><td>valid_loss</td><td>nan</td></tr><tr><td>valid_accuracy</td><td>0.50193</td></tr><tr><td>_runtime</td><td>965</td></tr><tr><td>_timestamp</td><td>1624578182</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█                     </td></tr><tr><td>train_accuracy</td><td>▇▇███████████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█                     </td></tr><tr><td>valid_accuracy</td><td>▇▇▇▇████▇████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">super-sweep-4</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/nt51sgpm" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/nt51sgpm</a><br/>
# wandb: Agent Starting Run: qtvi82mv with config:
# wandb: 	activation: elu
# wandb: 	architecture: densest_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.8
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">ethereal-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/qtvi82mv" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/qtvi82mv</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210624_234306-qtvi82mv</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 98168<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210624_234306-qtvi82mv/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210624_234306-qtvi82mv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.0043</td></tr><tr><td>train_accuracy</td><td>0.98359</td></tr><tr><td>valid_loss</td><td>0.00632</td></tr><tr><td>valid_accuracy</td><td>0.97223</td></tr><tr><td>_runtime</td><td>3385</td></tr><tr><td>_timestamp</td><td>1624581571</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>valid_loss</td><td>█▅▃▃▂▂▂▂▂▂▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▃▄▅▅▅▆▅▆▄▅▆▅▇▇▇▆▇▇▇▇▇▇█████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ethereal-sweep-5</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/qtvi82mv" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/qtvi82mv</a><br/>
# wandb: Agent Starting Run: wkz4fqwd with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.9
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.8
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">swept-sweep-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/wkz4fqwd" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/wkz4fqwd</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_003936-wkz4fqwd</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 125530<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_003936-wkz4fqwd/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_003936-wkz4fqwd/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00359</td></tr><tr><td>train_accuracy</td><td>0.99794</td></tr><tr><td>valid_loss</td><td>0.00431</td></tr><tr><td>valid_accuracy</td><td>0.98023</td></tr><tr><td>_runtime</td><td>565</td></tr><tr><td>_timestamp</td><td>1624582141</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▇▇▇▇▇▇▇█████████████████████████████</td></tr><tr><td>valid_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▅▆▆▆▇▇▇▇▇▇▇▇███████████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">swept-sweep-6</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/wkz4fqwd" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/wkz4fqwd</a><br/>
# wandb: Agent Starting Run: 08o1626u with config:
# wandb: 	activation: elu
# wandb: 	architecture: deeper_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.8
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">revived-sweep-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/08o1626u" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/08o1626u</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_004905-08o1626u</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 141589<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_004905-08o1626u/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_004905-08o1626u/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.02005</td></tr><tr><td>train_accuracy</td><td>0.96267</td></tr><tr><td>valid_loss</td><td>0.02019</td></tr><tr><td>valid_accuracy</td><td>0.94069</td></tr><tr><td>_runtime</td><td>508</td></tr><tr><td>_timestamp</td><td>1624582653</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">revived-sweep-7</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/08o1626u" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/08o1626u</a><br/>
# wandb: Agent Starting Run: br0aarkh with config:
# wandb: 	activation: elu
# wandb: 	architecture: deeper_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.8
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">stellar-sweep-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/br0aarkh" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/br0aarkh</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_005737-br0aarkh</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 157648<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_005737-br0aarkh/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_005737-br0aarkh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.02102</td></tr><tr><td>train_accuracy</td><td>0.96282</td></tr><tr><td>valid_loss</td><td>0.0192</td></tr><tr><td>valid_accuracy</td><td>0.946</td></tr><tr><td>_runtime</td><td>538</td></tr><tr><td>_timestamp</td><td>1624583195</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇▇▇▇███████████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▅▆▇▇▇▇▇▇▇▇▇▇███████████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stellar-sweep-8</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/br0aarkh" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/br0aarkh</a><br/>
# wandb: Agent Starting Run: vpf4g4cc with config:
# wandb: 	activation: elu
# wandb: 	architecture: densest_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.98
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">vocal-sweep-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/vpf4g4cc" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/vpf4g4cc</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_010639-vpf4g4cc</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 173707<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_010639-vpf4g4cc/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_010639-vpf4g4cc/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.06965</td></tr><tr><td>train_accuracy</td><td>0.91715</td></tr><tr><td>valid_loss</td><td>0.06679</td></tr><tr><td>valid_accuracy</td><td>0.90475</td></tr><tr><td>_runtime</td><td>1137</td></tr><tr><td>_timestamp</td><td>1624584336</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▂▄▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>valid_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▂▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">vocal-sweep-9</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/vpf4g4cc" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/vpf4g4cc</a><br/>
# wandb: Agent Starting Run: bob9xgnz with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.98
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">zany-sweep-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/bob9xgnz" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/bob9xgnz</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_012541-bob9xgnz</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 189788<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_012541-bob9xgnz/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_012541-bob9xgnz/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00583</td></tr><tr><td>train_accuracy</td><td>0.96917</td></tr><tr><td>valid_loss</td><td>0.00759</td></tr><tr><td>valid_accuracy</td><td>0.9643</td></tr><tr><td>_runtime</td><td>973</td></tr><tr><td>_timestamp</td><td>1624585314</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▃▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">zany-sweep-10</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/bob9xgnz" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/bob9xgnz</a><br/>
# wandb: Agent Starting Run: s52kip3q with config:
# wandb: 	activation: elu
# wandb: 	architecture: wider_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.8
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">sleek-sweep-11</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/s52kip3q" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/s52kip3q</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_014158-s52kip3q</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 217061<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_014158-s52kip3q/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_014158-s52kip3q/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.0182</td></tr><tr><td>train_accuracy</td><td>0.96211</td></tr><tr><td>valid_loss</td><td>0.02107</td></tr><tr><td>valid_accuracy</td><td>0.95318</td></tr><tr><td>_runtime</td><td>548</td></tr><tr><td>_timestamp</td><td>1624585866</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sleek-sweep-11</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/s52kip3q" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/s52kip3q</a><br/>
# wandb: Agent Starting Run: 9i270r1w with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.9
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">faithful-sweep-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/9i270r1w" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/9i270r1w</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_015110-9i270r1w</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 244320<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_015110-9i270r1w/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_015110-9i270r1w/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00384</td></tr><tr><td>train_accuracy</td><td>0.98765</td></tr><tr><td>valid_loss</td><td>0.00386</td></tr><tr><td>valid_accuracy</td><td>0.97346</td></tr><tr><td>_runtime</td><td>693</td></tr><tr><td>_timestamp</td><td>1624586563</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▃▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█▇▇████████████████</td></tr><tr><td>valid_loss</td><td>█▅▄▃▂▃▂▂▂▂▃▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▂▄▅▅▅▆▆▆▆▄▆▇▇▇▇▇▇▇▇▇▇▇█▇▇▇▇█▇██████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">faithful-sweep-12</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/9i270r1w" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/9i270r1w</a><br/>
# wandb: Agent Starting Run: 1zzsoo34 with config:
# wandb: 	activation: elu
# wandb: 	architecture: densest_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.98
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">radiant-sweep-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/1zzsoo34" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/1zzsoo34</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_020247-1zzsoo34</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 260385<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_020247-1zzsoo34/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_020247-1zzsoo34/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00151</td></tr><tr><td>train_accuracy</td><td>1.00494</td></tr><tr><td>valid_loss</td><td>0.00187</td></tr><tr><td>valid_accuracy</td><td>0.98545</td></tr><tr><td>_runtime</td><td>2189</td></tr><tr><td>_timestamp</td><td>1624588756</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▆▇▇▇▇▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>valid_loss</td><td>█▃▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▅▆▅▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">radiant-sweep-13</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/1zzsoo34" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/1zzsoo34</a><br/>
# wandb: Agent Starting Run: k05q638x with config:
# wandb: 	activation: elu
# wandb: 	architecture: wide_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.9
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.9
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">snowy-sweep-14</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/k05q638x" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/k05q638x</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_023921-k05q638x</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 276500<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_023921-k05q638x/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_023921-k05q638x/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.0205</td></tr><tr><td>train_accuracy</td><td>0.95441</td></tr><tr><td>valid_loss</td><td>0.01977</td></tr><tr><td>valid_accuracy</td><td>0.94133</td></tr><tr><td>_runtime</td><td>521</td></tr><tr><td>_timestamp</td><td>1624589282</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇▇▇▇▇████████████████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▆▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">snowy-sweep-14</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/k05q638x" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/k05q638x</a><br/>
# wandb: Agent Starting Run: sqrcgpmn with config:
# wandb: 	activation: elu
# wandb: 	architecture: deeper_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.9
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">wise-sweep-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/sqrcgpmn" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/sqrcgpmn</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_024808-sqrcgpmn</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 292559<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_024808-sqrcgpmn/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_024808-sqrcgpmn/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.09486</td></tr><tr><td>train_accuracy</td><td>0.90835</td></tr><tr><td>valid_loss</td><td>0.09022</td></tr><tr><td>valid_accuracy</td><td>0.89921</td></tr><tr><td>_runtime</td><td>600</td></tr><tr><td>_timestamp</td><td>1624589888</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...
# <br/>Waiting for W&B process to finish, PID 335879<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_030650-anp76lmp/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_030650-anp76lmp/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.03307</td></tr><tr><td>train_accuracy</td><td>0.95056</td></tr><tr><td>valid_loss</td><td>0.03505</td></tr><tr><td>valid_accuracy</td><td>0.93517</td></tr><tr><td>_runtime</td><td>553</td></tr><tr><td>_timestamp</td><td>1624590963</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">gentle-sweep-17</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/anp76lmp" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/anp76lmp</a><br/>
# wandb: Agent Starting Run: m49ypjum with config:
# wandb: 	activation: elu
# wandb: 	architecture: densest_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.8
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">faithful-sweep-18</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/m49ypjum" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/m49ypjum</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_031608-m49ypjum</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 351940<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_031608-m49ypjum/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_031608-m49ypjum/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00151</td></tr><tr><td>train_accuracy</td><td>0.99461</td></tr><tr><td>valid_loss</td><td>0.00191</td></tr><tr><td>valid_accuracy</td><td>0.98548</td></tr><tr><td>_runtime</td><td>1545</td></tr><tr><td>_timestamp</td><td>1624592513</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▃▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>valid_loss</td><td>█▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▃▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇██▇█▇████████████████▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">faithful-sweep-18</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/m49ypjum" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/m49ypjum</a><br/>
# wandb: Agent Starting Run: 8jdhlmrs with config:
# wandb: 	activation: elu
# wandb: 	architecture: densest_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-06
# wandb: 	momentum: 0.9
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">rural-sweep-19</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/8jdhlmrs" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/8jdhlmrs</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_034158-8jdhlmrs</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 379233<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_034158-8jdhlmrs/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_034158-8jdhlmrs/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00505</td></tr><tr><td>train_accuracy</td><td>0.98094</td></tr><tr><td>valid_loss</td><td>0.0078</td></tr><tr><td>valid_accuracy</td><td>0.96884</td></tr><tr><td>_runtime</td><td>3433</td></tr><tr><td>_timestamp</td><td>1624595951</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇█▇▇▇██████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">rural-sweep-19</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/8jdhlmrs" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/8jdhlmrs</a><br/>
# wandb: Agent Starting Run: 5e757337 with config:
# wandb: 	activation: elu
# wandb: 	architecture: denser_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: None
# wandb: 	learning_rate: 0.0005
# wandb: 	momentum: 0.98
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">vibrant-sweep-20</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/5e757337" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/5e757337</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_043916-5e757337</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 406592<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_043916-5e757337/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_043916-5e757337/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.01146</td></tr><tr><td>train_accuracy</td><td>0.9624</td></tr><tr><td>valid_loss</td><td>0.01289</td></tr><tr><td>valid_accuracy</td><td>0.95435</td></tr><tr><td>_runtime</td><td>745</td></tr><tr><td>_timestamp</td><td>1624596702</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇███▇████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">vibrant-sweep-20</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/5e757337" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/5e757337</a><br/>
# wandb: Agent Starting Run: zp00vpf0 with config:
# wandb: 	activation: elu
# wandb: 	architecture: wide_omata
# wandb: 	batch_size: 128
# wandb: 	beta_2: 0.9
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 5e-05
# wandb: 	momentum: 0.8
# wandb: 	optimizer: nadam
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">spring-sweep-21</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/zp00vpf0" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/zp00vpf0</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_045147-zp00vpf0</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 433859<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210625_045147-zp00vpf0/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210625_045147-zp00vpf0/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>199</td></tr><tr><td>train_loss</td><td>0.00492</td></tr><tr><td>train_accuracy</td><td>0.98976</td></tr><tr><td>valid_loss</td><td>0.00542</td></tr><tr><td>valid_accuracy</td><td>0.96937</td></tr><tr><td>_runtime</td><td>526</td></tr><tr><td>_timestamp</td><td>1624597233</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>valid_loss</td><td>█▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>valid_accuracy</td><td>▁▄▄▅▅▅▆▆▇▇▇▇▆▇▆▇▇▇▇▇██▇▇███▇████████████</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">spring-sweep-21</strong>: <a href="https://wandb.ai/zeff020/cae-fpc/runs/zp00vpf0" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/zp00vpf0</a><br/>
# wandb: Agent Starting Run: m69kx5kb with config:
# wandb: 	activation: elu
# wandb: 	architecture: deeper_omata
# wandb: 	batch_size: 64
# wandb: 	beta_2: 0.99999
# wandb: 	datafile: /content/drive/MyDrive/Colab Notebooks/data/processed/snaphsots_field_Velocity_new_4_2000steps.npy
# wandb: 	dense_activation: relu
# wandb: 	learning_rate: 0.0005
# wandb: 	momentum: 0.98
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.32<br/>
#                 Syncing run <strong style="color:#cdcd00">serene-sweep-22</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/zeff020/cae-fpc" target="_blank">https://wandb.ai/zeff020/cae-fpc</a><br/>
#                 Sweep page: <a href="https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7" target="_blank">https://wandb.ai/zeff020/cae-fpc/sweeps/nunpy3f7</a><br/>
# Run page: <a href="https://wandb.ai/zeff020/cae-fpc/runs/m69kx5kb" target="_blank">https://wandb.ai/zeff020/cae-fpc/runs/m69kx5kb</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210625_050038-m69kx5kb</code><br/><br/>
